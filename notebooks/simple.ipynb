# %%
run seasurface.py

# %%
run apertures.py

# %%
run observables.py

# %%
run seasurface_dynamic.py fields
# Out:
# Generating calm time series (advection=True)...
#   Saved timeseries_calm_sst.npy and timeseries_calm_ssh.npy
# Generating langmuir time series (advection=True)...
#   Saved timeseries_langmuir_sst.npy and timeseries_langmuir_ssh.npy
# Generating turbulent time series (advection=True)...
#   Saved timeseries_turbulent_sst.npy and timeseries_turbulent_ssh.npy

# %%
run seasurface_dynamic.py spectra --load timeseries_langmuir_sst.npy

# %%
run observables_batch.py --load timeseries_langmuir_ssh.npy --aperture golay9 --output test
# Out:
# Loading time series from timeseries_langmuir_ssh.npy
#   Shape: 301 frames, 256×256 pixels
# Computing reference spectra from original time series…
#   Reference statistics ready.
# Generating observed sequence for aperture 'golay9'…
#   Saved observed frames to test_observed.npy
# Computing radial power spectra (frame‑wise)…
#   Done.
# Computing spectral moment tensors (frame‑wise)…
#   Done.
# Computing anisotropy & orientation (frame‑wise)…
#   Done.
#   Saved spectral data to test_spectra.npz
# Saved figure: test_spectra.png
# Processing complete.
